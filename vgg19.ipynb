# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow.keras as K
import numpy as np 
import pandas as pd 
import cv2
import os
import matplotlib.pyplot as mpl
import pandas as pd
import numpy as np
from tensorflow.keras.saving import load_model
import tensorflow as tf
from sklearn.decomposition import PCA
from xgboost import XGBClassifier

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, applications
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras import Sequential


v19_model = applications.VGG19(weights="imagenet", include_top=False, input_shape=(32, 32, 3))


for i in v19_model.layers:
    i.trainable = False  
    
def invert_threshold(image, threshold=0.5):
    inverted_image = tf.where(image > threshold, 0.0, 1.0) 
    return inverted_image


train_dir = '/kaggle/input/gujarati-p-data/gujarati-handwritten-digit-dataset-master/Train Set'
test_dir = '/kaggle/input/gujarati-p-data/gujarati-handwritten-digit-dataset-master/Test Set'


train_datagen = ImageDataGenerator(
    preprocessing_function=lambda x: invert_threshold(x / 255.0)
)

test_datagen = ImageDataGenerator(
    preprocessing_function=lambda x: invert_threshold(x / 255.0)
)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(32, 32),  
    color_mode='grayscale',  
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(32, 32),  
    color_mode='grayscale',  
    batch_size=32,
    class_mode='categorical'
)

model = Sequential()


model.add(layers.Input(shape=(32, 32, 1)))


model.add(layers.Conv2D(3, (1, 1), padding='same'))


model.add(v19_model)


model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(Dense(10, activation='softmax'))


model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=2e-5),
              metrics=['accuracy'])


early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)


model.fit(
    train_generator,
    epochs=100,
    validation_data=test_generator,
    callbacks=[early_stopping]
)


test_loss, test_acc = model.evaluate(test_generator, verbose=2)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# Found 5600 images belonging to 10 classes.
# Found 2400 images belonging to 10 classes.
# Epoch 1/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 17s 82ms/step - accuracy: 0.3626 - loss: 1.9979 - val_accuracy: 0.8217 - val_loss: 1.3002
# Epoch 2/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 79ms/step - accuracy: 0.7765 - loss: 1.1672 - val_accuracy: 0.8746 - val_loss: 0.8530
# Epoch 3/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.8677 - loss: 0.7744 - val_accuracy: 0.8963 - val_loss: 0.6254
# Epoch 4/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 79ms/step - accuracy: 0.8835 - loss: 0.5714 - val_accuracy: 0.9104 - val_loss: 0.4910
# Epoch 5/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - accuracy: 0.9080 - loss: 0.4576 - val_accuracy: 0.9175 - val_loss: 0.4100
# Epoch 6/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.9196 - loss: 0.3780 - val_accuracy: 0.9267 - val_loss: 0.3493
# Epoch 7/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 79ms/step - accuracy: 0.9298 - loss: 0.3144 - val_accuracy: 0.9329 - val_loss: 0.3067
# Epoch 8/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9411 - loss: 0.2778 - val_accuracy: 0.9379 - val_loss: 0.2764
# Epoch 9/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - accuracy: 0.9442 - loss: 0.2513 - val_accuracy: 0.9383 - val_loss: 0.2504
# Epoch 10/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - accuracy: 0.9440 - loss: 0.2372 - val_accuracy: 0.9425 - val_loss: 0.2296
# Epoch 11/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - accuracy: 0.9469 - loss: 0.2189 - val_accuracy: 0.9442 - val_loss: 0.2137
# Epoch 12/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - accuracy: 0.9531 - loss: 0.1910 - val_accuracy: 0.9488 - val_loss: 0.2002
# Epoch 13/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.9560 - loss: 0.1748 - val_accuracy: 0.9496 - val_loss: 0.1910
# Epoch 14/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - accuracy: 0.9559 - loss: 0.1733 - val_accuracy: 0.9500 - val_loss: 0.1822
# Epoch 15/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9568 - loss: 0.1667 - val_accuracy: 0.9538 - val_loss: 0.1728
# Epoch 16/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9620 - loss: 0.1579 - val_accuracy: 0.9550 - val_loss: 0.1653
# Epoch 17/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9684 - loss: 0.1398 - val_accuracy: 0.9575 - val_loss: 0.1589
# Epoch 18/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - accuracy: 0.9665 - loss: 0.1377 - val_accuracy: 0.9571 - val_loss: 0.1524
# Epoch 19/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 79ms/step - accuracy: 0.9695 - loss: 0.1300 - val_accuracy: 0.9596 - val_loss: 0.1477
# Epoch 20/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9668 - loss: 0.1287 - val_accuracy: 0.9588 - val_loss: 0.1443
# Epoch 21/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9696 - loss: 0.1230 - val_accuracy: 0.9588 - val_loss: 0.1381
# Epoch 22/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9698 - loss: 0.1256 - val_accuracy: 0.9604 - val_loss: 0.1350
# Epoch 23/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 135ms/step - accuracy: 0.9717 - loss: 0.1146 - val_accuracy: 0.9592 - val_loss: 0.1359
# Epoch 24/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9727 - loss: 0.1055 - val_accuracy: 0.9617 - val_loss: 0.1276
# Epoch 25/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - accuracy: 0.9714 - loss: 0.1066 - val_accuracy: 0.9646 - val_loss: 0.1263
# Epoch 26/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - accuracy: 0.9735 - loss: 0.1033 - val_accuracy: 0.9638 - val_loss: 0.1217
# Epoch 27/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - accuracy: 0.9699 - loss: 0.1043 - val_accuracy: 0.9646 - val_loss: 0.1202
# Epoch 28/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9705 - loss: 0.1039 - val_accuracy: 0.9654 - val_loss: 0.1191
# Epoch 29/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9717 - loss: 0.1029 - val_accuracy: 0.9633 - val_loss: 0.1186
# Epoch 30/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9754 - loss: 0.0934 - val_accuracy: 0.9638 - val_loss: 0.1145
# Epoch 31/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9748 - loss: 0.0923 - val_accuracy: 0.9650 - val_loss: 0.1152
# Epoch 32/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9754 - loss: 0.0931 - val_accuracy: 0.9642 - val_loss: 0.1101
# Epoch 33/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9762 - loss: 0.0868 - val_accuracy: 0.9654 - val_loss: 0.1071
# Epoch 34/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - accuracy: 0.9766 - loss: 0.0860 - val_accuracy: 0.9663 - val_loss: 0.1076
# Epoch 35/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9751 - loss: 0.0855 - val_accuracy: 0.9650 - val_loss: 0.1077
# Epoch 36/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9751 - loss: 0.0889 - val_accuracy: 0.9658 - val_loss: 0.1061
# Epoch 37/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.9734 - loss: 0.0913 - val_accuracy: 0.9679 - val_loss: 0.1024
# Epoch 38/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 17s 94ms/step - accuracy: 0.9771 - loss: 0.0804 - val_accuracy: 0.9675 - val_loss: 0.1020
# Epoch 39/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 79ms/step - accuracy: 0.9765 - loss: 0.0796 - val_accuracy: 0.9667 - val_loss: 0.1013
# Epoch 40/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 79ms/step - accuracy: 0.9785 - loss: 0.0779 - val_accuracy: 0.9667 - val_loss: 0.1005
# Epoch 41/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.9809 - loss: 0.0710 - val_accuracy: 0.9675 - val_loss: 0.0986
# Epoch 42/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - accuracy: 0.9777 - loss: 0.0777 - val_accuracy: 0.9671 - val_loss: 0.0995
# Epoch 43/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 79ms/step - accuracy: 0.9818 - loss: 0.0644 - val_accuracy: 0.9683 - val_loss: 0.0967
# Epoch 44/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9844 - loss: 0.0681 - val_accuracy: 0.9671 - val_loss: 0.0984
# Epoch 45/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - accuracy: 0.9810 - loss: 0.0686 - val_accuracy: 0.9679 - val_loss: 0.0947
# Epoch 46/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 120ms/step - accuracy: 0.9821 - loss: 0.0698 - val_accuracy: 0.9692 - val_loss: 0.0943
# Epoch 47/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9853 - loss: 0.0622 - val_accuracy: 0.9700 - val_loss: 0.0965
# Epoch 48/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - accuracy: 0.9816 - loss: 0.0689 - val_accuracy: 0.9696 - val_loss: 0.0941
# Epoch 49/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - accuracy: 0.9790 - loss: 0.0691 - val_accuracy: 0.9692 - val_loss: 0.0937
# Epoch 50/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.9819 - loss: 0.0646 - val_accuracy: 0.9679 - val_loss: 0.0941
# Epoch 51/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9808 - loss: 0.0674 - val_accuracy: 0.9692 - val_loss: 0.0915
# Epoch 52/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9807 - loss: 0.0690 - val_accuracy: 0.9700 - val_loss: 0.0912
# Epoch 53/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 76ms/step - accuracy: 0.9807 - loss: 0.0618 - val_accuracy: 0.9700 - val_loss: 0.0904
# Epoch 54/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - accuracy: 0.9818 - loss: 0.0598 - val_accuracy: 0.9704 - val_loss: 0.0880
# Epoch 55/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.9856 - loss: 0.0564 - val_accuracy: 0.9700 - val_loss: 0.0885
# Epoch 56/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - accuracy: 0.9838 - loss: 0.0533 - val_accuracy: 0.9692 - val_loss: 0.0921
# Epoch 57/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - accuracy: 0.9880 - loss: 0.0493 - val_accuracy: 0.9700 - val_loss: 0.0905
# 75/75 - 4s - 50ms/step - accuracy: 0.9704 - loss: 0.0880
# Test Accuracy: 97.04%

# %%
model.save('/kaggle/working/vgg19_97.keras')

# %%
i_m_4096=K.models.Model(inputs=i_m.inputs,outputs=i_m.layers[-3].output)
i_x_h=i_m_4096_c.predict(x)
i_x_h.shape
